# %%
import os
import shutil

# Function to rename and move the files
def rename_and_move_files(root_folder, destination_folder):
    for primary_folder in os.listdir(root_folder):
        primary_path = os.path.join(root_folder, primary_folder)
        if os.path.isdir(primary_path):
            for secondary_folder in os.listdir(primary_path):
                secondary_path = os.path.join(primary_path, secondary_folder)
                if os.path.isdir(secondary_path):
                    for filename in os.listdir(secondary_path):
                        if filename.startswith("combined_image"):
                            old_filepath = os.path.join(secondary_path, filename)
                            new_filename = f"{primary_folder}-{secondary_folder}-{filename}"
                            new_filepath = os.path.join(destination_folder, new_filename)
                            shutil.move(old_filepath, new_filepath)

# Main function
def main():
    root_folder = "./rsna_preprocessing_output"  # Change this to your main directory
    destination_folder = "./restructure"  # Change this to your destination directory
    os.makedirs(destination_folder, exist_ok=True)  # Create the destination folder if it doesn't exist
    rename_and_move_files(root_folder, destination_folder)

if __name__ == "__main__":
    main()

# %%
import os
from collections import defaultdict
from PIL import Image

def combine_images_in_folder(folder_path, output_folder):
    # Dictionary to store image paths by their prefix
    image_paths = defaultdict(list)
    
    # Iterate over files in the folder
    for filename in os.listdir(folder_path):
        if filename.endswith(".jpg"):
            prefix = filename.rsplit("-", 1)[0]  # Extract prefix from filename
            image_paths[prefix].append(os.path.join(folder_path, filename))
    
    # Combine images
    for prefix, paths in image_paths.items():
        if len(paths) == 3:  # Ensure there are x, y, z images for this prefix
            output_path = os.path.join(output_folder, f"{prefix}-combined_rgb_image.jpg")
            combine_images(paths[0], paths[1], paths[2], output_path)

def combine_images(image_x_path, image_y_path, image_z_path, output_path):
    # Open the grayscale images
    image_x = Image.open(image_x_path)
    image_y = Image.open(image_y_path)
    image_z = Image.open(image_z_path)
    
    # Ensure images have the same size
    width, height = image_x.size
    assert (width, height) == image_y.size == image_z.size, "Images must have the same size"
    
    # Create a new RGB image
    combined_image = Image.new("RGB", (width, height))
    
    # Iterate over each pixel and set RGB values
    for y in range(height):
        for x in range(width):
            # Get pixel values from each image
            pixel_x = image_x.getpixel((x, y))[0]
            pixel_y = image_y.getpixel((x, y))[0]
            pixel_z = image_z.getpixel((x, y))[0]
            
            # Create RGB tuple
            rgb_pixel = (pixel_x, pixel_y, pixel_z)
            
            # Set RGB value in combined image
            combined_image.putpixel((x, y), rgb_pixel)
    
    # Save the combined image
    combined_image.save(output_path)
    print(f"Combined image saved at {output_path}")

# Example usage
combine_images_in_folder("./restructure", "./combined_rgb")
# Out:
# Combined image saved at ./combined_rgb/32943-22788-combined_rgb_image.jpg
# Combined image saved at ./combined_rgb/42134-37709-combined_rgb_image.jpg
# Combined image saved at ./combined_rgb/44001-5460-combined_rgb_image.jpg
# Combined image saved at ./combined_rgb/48681-13095-combined_rgb_image.jpg
# Combined image saved at ./combined_rgb/732-26337-combined_rgb_image.jpg
# Combined image saved at ./combined_rgb/37169-26343-combined_rgb_image.jpg
# Combined image saved at ./combined_rgb/64469-34841-combined_rgb_image.jpg
# Combined image saved at ./combined_rgb/12685-9181-combined_rgb_image.jpg
# Combined image saved at ./combined_rgb/9813-24149-combined_rgb_image.jpg
# Combined image saved at ./combined_rgb/56038-6467-combined_rgb_image.jpg
# Combined image saved at ./combined_rgb/30515-12104-combined_rgb_image.jpg
# Combined image saved at ./combined_rgb/59938-41040-combined_rgb_image.jpg
# Combined image saved at ./combined_rgb/42602-34191-combined_rgb_image.jpg
# Combined image saved at ./combined_rgb/63472-43690-combined_rgb_image.jpg
# Combined image saved at ./combined_rgb/24103-56184-combined_rgb_image.jpg
# Combined image saved at ./combined_rgb/4645-14642-combined_rgb_image.jpg
# Combined image saved at ./combined_rgb/64263-40690-combined_rgb_image.jpg
# Combined image saved at ./combined_rgb/21253-63049-combined_rgb_image.jpg
# Combined image saved at ./combined_rgb/58834-47353-combined_rgb_image.jpg
# Combined image saved at ./combined_rgb/21402-3339-combined_rgb_image.jpg
# Combined image saved at ./combined_rgb/42592-13342-combined_rgb_image.jpg
# Combined image saved at ./combined_rgb/13604-24652-combined_rgb_image.jpg
# Combined image saved at ./combined_rgb/20297-28647-combined_rgb_image.jpg
# Combined image saved at ./combined_rgb/13550-40313-combined_rgb_image.jpg
# Combined image saved at ./combined_rgb/56503-62450-combined_rgb_image.jpg
# Combined image saved at ./combined_rgb/41845-12696-combined_rgb_image.jpg
# Combined image saved at ./combined_rgb/2602-38305-combined_rgb_image.jpg
# Combined image saved at ./combined_rgb/61425-19028-combined_rgb_image.jpg
# Combined image saved at ./combined_rgb/27884-54341-combined_rgb_image.jpg
# Combined image saved at ./combined_rgb/53186-4646-combined_rgb_image.jpg
# Combined image saved at ./combined_rgb/10232-14541-combined_rgb_image.jpg
# Combined image saved at ./combined_rgb/63877-49697-combined_rgb_image.jpg
# Combined image saved at ./combined_rgb/52993-42914-combined_rgb_image.jpg
# Combined image saved at ./combined_rgb/53900-17012-combined_rgb_image.jpg
# Combined image saved at ./combined_rgb/2209-21338-combined_rgb_image.jpg
# Combined image saved at ./combined_rgb/42617-30684-combined_rgb_image.jpg
# Combined image saved at ./combined_rgb/42109-56044-combined_rgb_image.jpg
# Combined image saved at ./combined_rgb/17381-10099-combined_rgb_image.jpg
# Combined image saved at ./combined_rgb/23311-2339-combined_rgb_image.jpg
# Combined image saved at ./combined_rgb/51822-15854-combined_rgb_image.jpg
# Combined image saved at ./combined_rgb/36367-60813-combined_rgb_image.jpg
# Combined image saved at ./combined_rgb/4148-27542-combined_rgb_image.jpg
# Combined image saved at ./combined_rgb/10430-47009-combined_rgb_image.jpg
# Combined image saved at ./combined_rgb/35580-58392-combined_rgb_image.jpg
# Combined image saved at ./combined_rgb/21673-13545-combined_rgb_image.jpg
# Combined image saved at ./combined_rgb/27954-20290-combined_rgb_image.jpg
# Combined image saved at ./combined_rgb/15335-13697-combined_rgb_image.jpg
# Combined image saved at ./combined_rgb/36150-26228-combined_rgb_image.jpg
# Combined image saved at ./combined_rgb/23241-9031-combined_rgb_image.jpg
# Combined image saved at ./combined_rgb/12086-16498-combined_rgb_image.jpg
# Combined image saved at ./combined_rgb/40754-48977-combined_rgb_image.jpg
# Combined image saved at ./combined_rgb/12347-11403-combined_rgb_image.jpg
# Combined image saved at ./combined_rgb/45796-58131-combined_rgb_image.jpg
# Combined image saved at ./combined_rgb/50518-1201-combined_rgb_image.jpg
# Combined image saved at ./combined_rgb/18769-17758-combined_rgb_image.jpg
# Combined image saved at ./combined_rgb/63457-60877-combined_rgb_image.jpg
# Combined image saved at ./combined_rgb/32425-26840-combined_rgb_image.jpg
# Combined image saved at ./combined_rgb/54596-1808-combined_rgb_image.jpg
# Combined image saved at ./combined_rgb/27289-13087-combined_rgb_image.jpg
# Combined image saved at ./combined_rgb/49219-56469-combined_rgb_image.jpg
# Combined image saved at ./combined_rgb/30078-21759-combined_rgb_image.jpg
# Combined image saved at ./combined_rgb/7611-41113-combined_rgb_image.jpg
# Combined image saved at ./combined_rgb/21734-4209-combined_rgb_image.jpg
# Combined image saved at ./combined_rgb/9980-40466-combined_rgb_image.jpg
# Combined image saved at ./combined_rgb/16494-44612-combined_rgb_image.jpg
# Combined image saved at ./combined_rgb/42488-46934-combined_rgb_image.jpg
# Combined image saved at ./combined_rgb/24528-33573-combined_rgb_image.jpg
# Combined image saved at ./combined_rgb/23817-54015-combined_rgb_image.jpg
# Combined image saved at ./combined_rgb/50179-34772-combined_rgb_image.jpg
# Combined image saved at ./combined_rgb/28485-2929-combined_rgb_image.jpg
# Combined image saved at ./combined_rgb/34869-35546-combined_rgb_image.jpg
# Combined image saved at ./combined_rgb/38109-18256-combined_rgb_image.jpg
# Combined image saved at ./combined_rgb/6186-26927-combined_rgb_image.jpg
# Combined image saved at ./combined_rgb/42046-48762-combined_rgb_image.jpg
# Combined image saved at ./combined_rgb/48857-56975-combined_rgb_image.jpg
# Combined image saved at ./combined_rgb/27291-2839-combined_rgb_image.jpg
# Combined image saved at ./combined_rgb/28468-4310-combined_rgb_image.jpg
# Combined image saved at ./combined_rgb/63449-18981-combined_rgb_image.jpg
# Combined image saved at ./combined_rgb/52106-44841-combined_rgb_image.jpg
# Combined image saved at ./combined_rgb/13012-38013-combined_rgb_image.jpg
# Combined image saved at ./combined_rgb/5973-40903-combined_rgb_image.jpg
# Combined image saved at ./combined_rgb/44649-50198-combined_rgb_image.jpg
# Combined image saved at ./combined_rgb/35723-6714-combined_rgb_image.jpg
# Combined image saved at ./combined_rgb/58810-45230-combined_rgb_image.jpg
# Combined image saved at ./combined_rgb/27971-55548-combined_rgb_image.jpg
# Combined image saved at ./combined_rgb/16450-30471-combined_rgb_image.jpg
# Combined image saved at ./combined_rgb/17252-29243-combined_rgb_image.jpg
# Combined image saved at ./combined_rgb/17592-33237-combined_rgb_image.jpg
# Combined image saved at ./combined_rgb/43762-7198-combined_rgb_image.jpg
# Combined image saved at ./combined_rgb/7162-16162-combined_rgb_image.jpg
# Combined image saved at ./combined_rgb/44951-29596-combined_rgb_image.jpg
# Combined image saved at ./combined_rgb/46630-39471-combined_rgb_image.jpg
# Combined image saved at ./combined_rgb/48265-56576-combined_rgb_image.jpg
# Combined image saved at ./combined_rgb/46680-58148-combined_rgb_image.jpg
# Combined image saved at ./combined_rgb/25869-56457-combined_rgb_image.jpg
# Combined image saved at ./combined_rgb/39127-24349-combined_rgb_image.jpg
# Combined image saved at ./combined_rgb/49390-62702-combined_rgb_image.jpg
# Combined image saved at ./combined_rgb/21293-27585-combined_rgb_image.jpg
# Combined image saved at ./combined_rgb/58729-7818-combined_rgb_image.jpg
# Combined image saved at ./combined_rgb/57058-10506-combined_rgb_image.jpg
# Combined image saved at ./combined_rgb/65083-64311-combined_rgb_image.jpg
# Combined image saved at ./combined_rgb/35294-28450-combined_rgb_image.jpg
# Combined image saved at ./combined_rgb/51026-8401-combined_rgb_image.jpg
# Combined image saved at ./combined_rgb/39127-24349-combined_rgb_image.jpg
# Combined image saved at ./combined_rgb/49390-62702-combined_rgb_image.jpg
# Combined image saved at ./combined_rgb/21293-27585-combined_rgb_image.jpg
# Combined image saved at ./combined_rgb/58729-7818-combined_rgb_image.jpg
# Combined image saved at ./combined_rgb/57058-10506-combined_rgb_image.jpg
# Combined image saved at ./combined_rgb/65083-64311-combined_rgb_image.jpg
# Combined image saved at ./combined_rgb/35294-28450-combined_rgb_image.jpg
# Combined image saved at ./combined_rgb/51026-8401-combined_rgb_image.jpg

# %%
import os
import shutil
import pandas as pd
import random

# Read train.csv file
csv_file_path = 'train.csv'
df = pd.read_csv(csv_file_path)

# Check if required columns exist
required_columns = ['patient_id', 'any_injury']
if not all(column in df.columns for column in required_columns):
    raise ValueError("Required columns not found in the CSV file.")

# Extract patient IDs from filenames and create mapping
patient_id_mapping = {}
image_folder_path = './combined_rgb'  # Assuming images are in the current directory
for filename in os.listdir(image_folder_path):
    if filename.endswith('.jpg'):
        parts = filename.split('-')
        patient_id = parts[0]
        patient_id_mapping[filename] = int(df[df['patient_id'] == int(patient_id)]['any_injury'])

# Define paths for the dataset
dataset_path = 'dataset'
train_path = os.path.join(dataset_path, 'Train')
val_path = os.path.join(dataset_path, 'Validation')
test_path = os.path.join(dataset_path, 'Test')

# Create directories for the dataset
for path in [train_path, val_path, test_path]:
    os.makedirs(os.path.join(path, 'Any_injury_0'), exist_ok=True)
    os.makedirs(os.path.join(path, 'Any_injury_1'), exist_ok=True)

# Class imbalance handling: Count occurrences of each class
class_counts = {0: 0, 1: 0}
for label in patient_id_mapping.values():
    class_counts[label] += 1

# Determine undersampling ratio
undersampling_ratio = min(class_counts.values()) / max(class_counts.values())

# Shuffle and split filenames into train, validation, and test sets
filenames = list(patient_id_mapping.keys())
random.shuffle(filenames)
train_size = int(0.6 * len(filenames))
val_size = int(0.2 * len(filenames))
test_size = int(0.2 * len(filenames))

train_filenames = filenames[:train_size]
val_filenames = filenames[train_size:train_size + val_size]
test_filenames = filenames[train_size + val_size:]

# Function to move images to appropriate folders and perform undersampling
def move_images(filenames, destination_path):
    for filename in filenames:
        label = patient_id_mapping[filename]
        source_path = os.path.join(image_folder_path, filename)
        if random.random() > undersampling_ratio and class_counts[label] > min(class_counts.values()):
            # Skip the image for undersampling
            continue
        shutil.copy(source_path, os.path.join(destination_path, f'Any_injury_{label}', filename))
        class_counts[label] -= 1

# Move images to train, validation, and test folders
move_images(train_filenames, train_path)
move_images(val_filenames, val_path)
move_images(test_filenames, test_path)

print("Dataset creation completed.")
